# %%
import sys
sys.path.append('/usr/local/lib/python3.5/dist-packages')

from deco import *

# %%
@concurrent # We add this for the concurrent function
def determinant(n,m):
    """Compute determinant"""
    mat = np.random.rand(n,m)
    return np.linalg.det(mat)

@synchronized # And we add this for the function which calls the concurrent function
def process_data_set():
    i = 0
    for n in [2000,2001,2002]:
        for m in [2000,2001,2002]:
            result = determinant(n,m)
            i += 1
            
    return result

# %%
process_data_set()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0be405be9605> in <module>()
# ----> 1 process_data_set()
#
# /usr/local/lib/python3.5/dist-packages/deco/conc.py in __call__(self, *args, **kwargs)
#      50             self.ast = ast.parse(source)
#      51             rewriter = astutil.SchedulerRewriter(concurrent.functions.keys())
# ---> 52             rewriter.visit(self.ast.body[0])
#      53             ast.fix_missing_locations(self.ast)
#      54             out = compile(self.ast, "<string>", "exec")
#
# /home/bergmann/anaconda3/envs/python2/lib/python2.7/ast.pyc in visit(self, node)
#     239         method = 'visit_' + node.__class__.__name__
#     240         visitor = getattr(self, method, self.generic_visit)
# --> 241         return visitor(node)
#     242
#     243     def generic_visit(self, node):
#
# /usr/local/lib/python3.5/dist-packages/deco/astutil.py in visit_FunctionDef(self, node)
#      97     def visit_FunctionDef(self, node):
#      98         node.decorator_list = []
# ---> 99         self.generic_visit(node)
#     100         node.body += self.get_waits()
#     101         return node
#
# /usr/local/lib/python3.5/dist-packages/deco/astutil.py in generic_visit(self, node)
#      67
#      68     def generic_visit(self, node):
# ---> 69         super(NodeTransformer, self).generic_visit(node)
#      70         if hasattr(node, 'body') and type(node.body) is list:
#      71             returns = [i for i, child in enumerate(node.body) if type(child) is ast.Return]
#
# /home/bergmann/anaconda3/envs/python2/lib/python2.7/ast.pyc in generic_visit(self, node)
#     247                 for item in value:
#     248                     if isinstance(item, AST):
# --> 249                         self.visit(item)
#     250             elif isinstance(value, AST):
#     251                 self.visit(value)
#
# /home/bergmann/anaconda3/envs/python2/lib/python2.7/ast.pyc in visit(self, node)
#     239         method = 'visit_' + node.__class__.__name__
#     240         visitor = getattr(self, method, self.generic_visit)
# --> 241         return visitor(node)
#     242
#     243     def generic_visit(self, node):
#
# /usr/local/lib/python3.5/dist-packages/deco/astutil.py in generic_visit(self, node)
#      67
#      68     def generic_visit(self, node):
# ---> 69         super(NodeTransformer, self).generic_visit(node)
#      70         if hasattr(node, 'body') and type(node.body) is list:
#      71             returns = [i for i, child in enumerate(node.body) if type(child) is ast.Return]
#
# /home/bergmann/anaconda3/envs/python2/lib/python2.7/ast.pyc in generic_visit(self, node)
#     247                 for item in value:
#     248                     if isinstance(item, AST):
# --> 249                         self.visit(item)
#     250             elif isinstance(value, AST):
#     251                 self.visit(value)
#
# /home/bergmann/anaconda3/envs/python2/lib/python2.7/ast.pyc in visit(self, node)
#     239         method = 'visit_' + node.__class__.__name__
#     240         visitor = getattr(self, method, self.generic_visit)
# --> 241         return visitor(node)
#     242
#     243     def generic_visit(self, node):
#
# /usr/local/lib/python3.5/dist-packages/deco/astutil.py in generic_visit(self, node)
#      77                 if type(child) is ast.Expr and self.is_concurrent_call(child.value):
#      78                     self.encounter_call(child.value)
# ---> 79                 elif self.is_valid_assignment(child):
#      80                     call = child.value
#      81                     self.encounter_call(call)
#
# /usr/local/lib/python3.5/dist-packages/deco/astutil.py in is_valid_assignment(self, node)
#      56             raise ValueError("Concurrent assignment does not support multiple assignment targets")
#      57         if not type(node.targets[0]) is ast.Subscript:
# ---> 58             raise ValueError("Concurrent assignment only valid for index based objects")
#      59         return True
#      60
#
# ValueError: Concurrent assignment only valid for index based objects

# %%
import deco
import time
import md5


def test_synchronous(sleep_time):
    starttime = time.time()
    m = md5.new("Nobody inspects the spammish repetition")
    count = 0
    while((time.time() - starttime) < sleep_time/1000.0):
        m.update("p")
        a = m.hexdigest()
        count += 1
    return count


@deco.concurrent
def test(sleep_time):
    starttime = time.time()
    m = md5.new("Nobody inspects the spammish repetition")
    count = 0
    while((time.time() - starttime) < sleep_time/1000.0):
        m.update(" repetition")
        a = m.hexdigest()
        count += 1
    return count

test_time = 2
if __name__ == "__main__":
    times = [0.001, 0.005, 0.01, 0.1, 0.5, 1, 2, 5, 10, 20, 30]
    print("Measuring hashes/sec with single threaded synchronous calls")
    for time_duration in times:
        hashes = 0
        start = time.time()
        iterations = int(test_time/(time_duration/1000.0))
        if iterations > 20000:
            iterations = 20000
        for _ in range(iterations):
            hashes += test_synchronous(time_duration)
        print(time_duration, hashes / (time.time() - start))
    print("Measuring hashes/sec with deco multiprocess calls (3 workers)")
    for time_duration in times:
        hashes = 0
        start = time.time()
        iterations = int(test_time/(time_duration/1000.0))
        if iterations > 20000:
            iterations = 20000
        for _ in range(iterations):
            test(time_duration)
        result = test.wait()
        hashes = sum(result)
print(hashes / (time.time() - start))
# Out:
# Measuring hashes/sec with single threaded synchronous calls
# (0.001, 293410.78725020646)
# (0.005, 571972.3872285642)
# (0.01, 701991.7935495035)
# (0.1, 813718.6054179607)
# (0.5, 857683.7123424081)
# (1, 775398.6813367498)
# (2, 785793.3551595066)
# (5, 792507.5323974395)
# (10, 769399.2296026304)
# (20, 772959.8591633522)
# (30, 773852.5019311471)
# Measuring hashes/sec with deco multiprocess calls (3 workers)
# 3061653.55102
